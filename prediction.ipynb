# %%
import os
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression 
from sklearn import preprocessing
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, roc_auc_score, confusion_matrix

# %%
#Get path
current_directory = os.getcwd()
current_directory

df = pd.read_csv(current_directory+'/datasets/df_prediction.csv')

# %%
#Review Dataset
df.head(40)
# Out:
#              player  year_month  sent_pga  pga_lag1  pga_lag2  pga_lag3  \
# 0     brooks koepka  2020-11-01  0.958400       NaN       NaN       NaN
# 1     brooks koepka  2021-02-01  0.790600  0.958400       NaN       NaN
# 2     brooks koepka  2021-04-01  0.670867  0.790600  0.958400       NaN
# 3     brooks koepka  2021-06-01  0.851413  0.670867  0.790600  0.958400
# 4     brooks koepka  2021-07-01  0.423000  0.851413  0.670867  0.790600
# 5     brooks koepka  2021-09-01       NaN       NaN       NaN       NaN
# 6     brooks koepka  2021-10-01  0.972567  0.423000  0.851413  0.670867
# 7     brooks koepka  2022-02-01  0.753200  0.972567  0.423000  0.851413
# 8     brooks koepka  2022-06-01  0.466633  0.753200  0.972567  0.423000
# 9     brooks koepka  2022-09-01       NaN       NaN       NaN       NaN
# 10    brooks koepka  2022-10-01       NaN       NaN       NaN       NaN
# 11    brooks koepka  2023-01-01       NaN       NaN       NaN       NaN
# 12    brooks koepka  2023-03-01  0.128000  0.466633  0.753200  0.972567
# 13    brooks koepka  2023-04-01  0.953060  0.128000  0.466633  0.753200
# 14    brooks koepka  2023-05-01  0.750189  0.953060  0.128000  0.466633
# 15    brooks koepka  2023-06-01  0.921233  0.750189  0.953060  0.128000
# 16    brooks koepka  2023-08-01       NaN       NaN       NaN       NaN
# 17    brooks koepka  2023-09-01       NaN       NaN       NaN       NaN
# 18    brooks koepka  2023-10-01       NaN       NaN       NaN       NaN
# 19    brooks koepka  2024-02-01       NaN       NaN       NaN       NaN
# 20    cameron smith  2021-01-01  0.591600       NaN       NaN       NaN
# 21    cameron smith  2021-03-01       NaN       NaN       NaN       NaN
# 22    cameron smith  2021-04-01  0.818300  0.591600       NaN       NaN
# 23    cameron smith  2021-06-01  0.865500  0.818300  0.591600       NaN
# 24    cameron smith  2021-08-01  0.648600  0.865500  0.818300  0.591600
# 25    cameron smith  2022-01-01  0.943340  0.648600  0.865500  0.818300
# 26    cameron smith  2022-02-01  0.785100  0.943340  0.648600  0.865500
# 27    cameron smith  2022-03-01       NaN       NaN       NaN       NaN
# 28    cameron smith  2022-04-01  0.802000  0.785100  0.943340  0.648600
# 29    cameron smith  2022-05-01  0.845700  0.802000  0.785100  0.943340
# 30    cameron smith  2022-06-01  0.885875  0.845700  0.802000  0.785100
# 31    cameron smith  2022-07-01       NaN       NaN       NaN       NaN
# 32    cameron smith  2022-08-01  0.840000  0.885875  0.845700  0.802000
# 33    cameron smith  2022-09-01  0.493900  0.840000  0.885875  0.845700
# 34    cameron smith  2022-10-01       NaN       NaN       NaN       NaN
# 35    cameron smith  2023-04-01       NaN       NaN       NaN       NaN
# 36    cameron smith  2023-05-01  0.855500  0.493900  0.840000  0.885875
# 37    cameron smith  2023-07-01       NaN       NaN       NaN       NaN
# 38  collin morikawa  2020-11-01  0.978850       NaN       NaN       NaN
# 39  collin morikawa  2020-12-01  0.991175  0.978850       NaN       NaN
#
#     sent_liv  sent_both  LIV_CHANGE
# 0   0.651700        NaN           0
# 1   0.839250        NaN           0
# 2        NaN        NaN           0
# 3   0.102600   0.962300           0
# 4        NaN        NaN           0
# 5   0.865800        NaN           0
# 6   0.632500        NaN           0
# 7   0.788750        NaN           0
# 8   0.892250        NaN           1
# 9   0.757900        NaN           0
# 10  0.584600   0.986400           0
# 11  0.296000   0.937100           0
# 12  0.153233   0.897600           0
# 13  0.672300   0.631875           0
# 14  0.947160   0.907550           0
# 15  0.774520   0.873625           0
# 16  0.926000        NaN           0
# 17  0.702717        NaN           0
# 18  0.795867        NaN           0
# 19  0.988250        NaN           0
# 20       NaN        NaN           0
# 21  0.632900        NaN           0
# 22       NaN        NaN           0
# 23       NaN        NaN           0
# 24       NaN        NaN           0
# 25       NaN        NaN           0
# 26       NaN        NaN           0
# 27  0.897967        NaN           0
# 28  0.886000        NaN           0
# 29       NaN        NaN           0
# 30  0.000000        NaN           0
# 31  0.113150        NaN           0
# 32  0.935400        NaN           1
# 33  0.823225   0.933100           0
# 34  0.818500        NaN           0
# 35  0.790913   0.969800           0
# 36  0.922600        NaN           0
# 37  0.672580   0.943775           0
# 38  0.984000        NaN           0
# 39       NaN        NaN           0

# %%
df.isna().mean()
# Out:
# player        0.000000
# year_month    0.000000
# sent_pga      0.200772
# pga_lag1      0.243243
# pga_lag2      0.285714
# pga_lag3      0.328185
# sent_liv      0.281853
# sent_both     0.679537
# LIV_CHANGE    0.000000
# dtype: float64

# %%
# Reset index

df['sent_pga'] = df.groupby('player')['sent_pga'].transform(lambda x: x.interpolate(method='linear'))
df['sent_liv'] = df.groupby('player')['sent_liv'].transform(lambda x: x.interpolate(method='linear')) # Media entre forward y back

df['pga_lag1'] = df.groupby('player')['pga_lag1'].transform(lambda x: x.ffill().bfill())

df['pga_lag2'] = df.groupby('player')['pga_lag2'].transform(lambda x: x.ffill().bfill())



# Forward fill and backward fill for other columns if necessary
# df['other_column'] = df.groupby('player')['other_column'].apply(lambda x: x.ffill().bfill())

# Linear interpolation for remaining missing values in other columns if necessary
# df['other_column'] = df.groupby('player')['other_column'].apply(lambda x: x.interpolate(method='linear'))

# %%
df['sent_pga'] = df.groupby('player')['sent_pga'].transform(lambda x: x.ffill().bfill())
df['sent_liv'] = df.groupby('player')['sent_liv'].transform(lambda x: x.ffill().bfill())

# %%
df = df.drop(['sent_both','pga_lag3'], axis=1)
#Quitar both

# %% [markdown]
# # Mark with one all the LIV players, try to predict with a random forest and logistic reg if that player is LIV...

# %%
df
# Out:
#             player  year_month  sent_pga  pga_lag1  pga_lag2  sent_liv  \
# 0    brooks koepka  2020-11-01  0.958400  0.958400  0.958400  0.651700
# 1    brooks koepka  2021-02-01  0.790600  0.958400  0.958400  0.839250
# 2    brooks koepka  2021-04-01  0.670867  0.790600  0.958400  0.470925
# 3    brooks koepka  2021-06-01  0.851413  0.670867  0.790600  0.102600
# 4    brooks koepka  2021-07-01  0.423000  0.851413  0.670867  0.484200
# ..             ...         ...       ...       ...       ...       ...
# 254  sergio garcia  2023-04-01  0.714000  0.732300  0.375300  0.607133
# 255  sergio garcia  2023-05-01  0.870600  0.557400  0.732300  0.992900
# 256  sergio garcia  2023-06-01  0.870600  0.557400  0.732300  0.517933
# 257  sergio garcia  2023-08-01  0.870600  0.557400  0.732300  0.970775
# 258  sergio garcia  2024-02-01  0.870600  0.557400  0.732300  0.670700
#
#      LIV_CHANGE
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ..          ...
# 254           0
# 255           0
# 256           0
# 257           0
# 258           0
#
# [259 rows x 7 columns]

# %%
X = df.drop('LIV_CHANGE', axis=1)
Y = df['LIV_CHANGE']

# %%
dummies = pd.get_dummies(X['player'], prefix='player')

# Concatenate the dummy variables DataFrame with the original DataFrame
X_with_dummies = pd.concat([X, dummies], axis=1)

# %% [markdown]
# ## Split Data

# %%
X_train, X_val, y_train, y_val = train_test_split(X_with_dummies, Y, 
                                                  test_size=0.20, stratify=df['LIV_CHANGE'], 
                                                  random_state=42)

# %%
train_categorical = X_train[['player','year_month']]
train_numerical = X_train[['sent_pga','pga_lag1','pga_lag2','sent_liv']]
val_categorical = X_val[['player','year_month']]
val_numerical = X_val[['sent_pga','pga_lag1','pga_lag2','sent_liv']]

# %% [markdown]
# # Need to separate Player and Date for the scaling

# %%
## SCALING
from sklearn.preprocessing import StandardScaler

# Initialize the scaler
scaler = StandardScaler()

# Fit the scaler to your training data and transform it
X_train_scaled = scaler.fit_transform(train_numerical)

# Transform your validation data using the scaler fitted on the training data
X_val_scaled = scaler.transform(val_numerical)

# %%
model = LogisticRegression()

model.fit(X_train_scaled,y_train)

# Make predictions
test_predictions = model.predict(X_val_scaled)

# calculate probas
test_predictions_prob = model.predict_proba(X_val_scaled)

# %%
test_predictions_prob
# Out:
# array([[0.98418905, 0.01581095],
#        [0.97367155, 0.02632845],
#        [0.98240136, 0.01759864],
#        [0.97851568, 0.02148432],
#        [0.99018218, 0.00981782],
#        [0.97738981, 0.02261019],
#        [0.97597776, 0.02402224],
#        [0.98976746, 0.01023254],
#        [0.98218514, 0.01781486],
#        [0.91361923, 0.08638077],
#        [0.98746171, 0.01253829],
#        [0.97936133, 0.02063867],
#        [0.9777406 , 0.0222594 ],
#        [0.989352  , 0.010648  ],
#        [0.97806749, 0.02193251],
#        [0.98733863, 0.01266137],
#        [0.98186341, 0.01813659],
#        [0.98095062, 0.01904938],
#        [0.98694754, 0.01305246],
#        [0.98187841, 0.01812159],
#        [0.98052652, 0.01947348],
#        [0.98048114, 0.01951886],
#        [0.9806401 , 0.0193599 ],
#        [0.97731878, 0.02268122],
#        [0.98268334, 0.01731666],
#        [0.98947625, 0.01052375],
#        [0.98609901, 0.01390099],
#        [0.98518518, 0.01481482],
#        [0.97421738, 0.02578262],
#        [0.98988115, 0.01011885],
#        [0.98499122, 0.01500878],
#        [0.97960364, 0.02039636],
#        [0.98064162, 0.01935838],
#        [0.98147148, 0.01852852],
#        [0.98630008, 0.01369992],
#        [0.97312124, 0.02687876],
#        [0.974855  , 0.025145  ],
#        [0.97180197, 0.02819803],
#        [0.98150092, 0.01849908],
#        [0.96080391, 0.03919609],
#        [0.97862483, 0.02137517],
#        [0.98069568, 0.01930432],
#        [0.98062865, 0.01937135],
#        [0.98205048, 0.01794952],
#        [0.98627361, 0.01372639],
#        [0.99541123, 0.00458877],
#        [0.94993289, 0.05006711],
#        [0.97969517, 0.02030483],
#        [0.95893741, 0.04106259],
#        [0.97170785, 0.02829215],
#        [0.98570234, 0.01429766],
#        [0.98296933, 0.01703067]])

# %%
# Random Forest classifier y ver las features.
